# %%
import pandas as pd
import numpy as np

import seaborn as sns
sns.set(style="white")
import matplotlib.pyplot as plt
import matplotlib as mpl


from sklearn.preprocessing import StandardScaler, normalize
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import(accuracy_score, roc_auc_score, f1_score, plot_confusion_matrix,
                            recall_score, confusion_matrix, precision_score, classification_report)

from sklearn.linear_model import LogisticRegression  
from sklearn.neighbors import KNeighborsClassifier

from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier

from sklearn import preprocessing
from IPython.display import display, HTML

#global variable
random_state=42

# %matplotlib inline

# %%
df=pd.read_csv('./data/churn.csv').drop(columns=['RowNumber','Surname', 'CustomerId', 'Geography'], axis=1)
df.head(3)
# Out:
#    CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619  Female   42       2       0.00              1          1
# 1          608  Female   41       1   83807.86              1          0
# 2          502  Female   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited
# 0               1        101348.88       1
# 1               1        112542.58       0
# 2               0        113931.57       1

# %%
df['Gender']=df['Gender'].apply(lambda x: 0 if x=='Female' else 1)

# %%
y = df["Exited"]
X = df.drop(["Exited"], axis = 1)

# %%
y.shape, X.shape
# Out:
# ((10000,), (10000, 9))

# %%
df.Exited.value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %% [markdown]
# unbalanced datasets relates to the metrics used to evaluate their model. Using simpler metrics like accuracy score can be misleading. In a dataset with highly unbalanced classes, the classifier will always “predicts” the most common class without performing any analysis of the features and it will have a high accuracy rate, obviously not the correct one.

# %% [markdown]
# ## Data splitting

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2, random_state=random_state)

# %% [markdown]
# It is important to train the models on a different subset
# of the training data than the linear regression model to avoid
# overfitting, in particular if the total number of leaves is
# similar to the number of training samples.

# %%
X_train, X_val, y_train, y_val=train_test_split(X_train, y_train, test_size=0.2, random_state=random_state)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train=scaler.transform(X_train)#train set scaled

# %%
X_val=scaler.transform(X_val)#validation set scaled

# %%
X_test=scaler.transform(X_test)#original dataset scaled

# %% [markdown]
# # Modeling
#
#
# - Logistic Classifier
# - GradientBoosting Classifier
# - Decision Tree Classifier
# - Random Forest Classifier
# - KNN Classifier

# %% [markdown]
# Skewed datasets are not uncommon. And they are tough to handle. Usual classification models and techniques often fail miserably when presented with such a problem. Although your model could get you to even a 99% accuracy on such cases, yet, if you are measuring yourself against a sensible metric such as the ROC Auc score, then you will face trouble getting up that leaderboard. This is because if the dataset is skewed, for example, a 10:1 ratio of Positives to Negatives occur, then by just predicting positives for every sample you see without any learning, you can get to a 90% accuracy score! So, how do we get around this problem? This post will highlight a few effective techniques you can use to do well on such tasks. The techniques range from differently sampling your data to setting some hyperparameters cleverly to using libraries that contain different versions of the usual algorithms which internally handle imbalance themselves.

# %%
# count examples in each class
from collections import Counter
counter = Counter(y_train)
# estimate scale_pos_weight value
estimate = counter[0] / counter[1]
print('Estimate: %.3f' % estimate)
# Out:
# Estimate: 3.860

# %% [markdown]
# ## KNeighborsClassifier

# %%
from sklearn import neighbors
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import cross_val_score
# define model
model = neighbors.KNeighborsClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
#print('Mean ROC AUC: %.5f' % mean(scores))
print("Mean ROC AUC: %.5f " % (scores.mean()))
# Out:
# Mean ROC AUC: 0.75912

# %%
# define grid
param_grid= {'weights':['uniform','distance'],'n_neighbors':[3,5,9,11]}
model =neighbors.KNeighborsClassifier()

# %%
# define evaluation procedure
from sklearn.model_selection import GridSearchCV
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X_train, y_train)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.794691 using {'n_neighbors': 11, 'weights': 'distance'}

# %%
knn= neighbors.KNeighborsClassifier(n_neighbors=11, weights='distance')
knn.fit(X_train, y_train)
y_pred=knn.predict(X_val)

# %% [markdown]
# ## Logistic Regression

# %%
#define model
model = LogisticRegression()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
#print('Mean ROC AUC: %.5f' % mean(scores))
print("Mean ROC AUC: %.5f " % (scores.mean()))
# Out:
# Mean ROC AUC: 0.74513

# %%
# define grid
param_grid= {'max_iter':[50,100,300],'penalty':['l2','l1']}
model =LogisticRegression(random_state=67)

# %%
# define evaluation procedure
from sklearn.model_selection import GridSearchCV
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X_train, y_train)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.745132 using {'max_iter': 50, 'penalty': 'l2'}

# %%
logit = LogisticRegression(max_iter=50, penalty='l2')
logit.fit(X_train, y_train)
y_pred=logit.predict(X_val)

# %% [markdown]
# ## DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
# define model
model = DecisionTreeClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
#print('Mean ROC AUC: %.5f' % mean(scores))
print("Mean ROC AUC: %.5f " % (scores.mean()))
# Out:
# Mean ROC AUC: 0.66743

# %%
# define grid
param_grid= {'max_depth':[1,3,5,9],'max_features':[3,5,7]}
model =DecisionTreeClassifier(random_state=76)

# %%
# define evaluation procedure
from sklearn.model_selection import GridSearchCV
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X_train, y_train)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.823332 using {'max_depth': 5, 'max_features': 5}

# %%
tree = DecisionTreeClassifier(max_depth=5, max_features=5)
tree.fit(X_train, y_train)
y_pred=tree.predict(X_val)

# %% [markdown]
# ## RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
# define model
model = RandomForestClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
#print('Mean ROC AUC: %.5f' % mean(scores))
print("Mean ROC AUC: %.5f " % (scores.mean()))
# Out:
# Mean ROC AUC: 0.82821

# %% [markdown]
# ## Tuning

# %%
# define grid
param_grid= {'n_estimators':[100,300,500],'max_depth':[1,3,5], 'max_features':[3,4,5]}
model =RandomForestClassifier(random_state=random_state)

# %%
# define evaluation procedure
from sklearn.model_selection import GridSearchCV
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X_train, y_train)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.843626 using {'max_depth': 5, 'max_features': 5, 'n_estimators': 300}

# %%
rf= RandomForestClassifier(max_depth=5,max_features=5, n_estimators=300)
rf.fit(X_train, y_train)
y_pred=rf.predict(X_val)

# %%
print(classification_report(y_val, y_pred, digits=2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      1273
#            1       0.81      0.43      0.57       327
#
#     accuracy                           0.86      1600
#    macro avg       0.84      0.70      0.74      1600
# weighted avg       0.86      0.86      0.85      1600

# %%
# Plot non-normalized confusion matrix
disp = plot_confusion_matrix(rf, X_val, y_val,cmap=plt.cm.Blues)
disp.ax_.set_title("Confusion matrix, without normalization")
plt.show()

# %% [markdown]
# ## GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
# define model
model = GradientBoostingClassifier()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X_train, y_train, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
#print('Mean ROC AUC: %.5f' % mean(scores))
print("Mean ROC AUC: %.5f " % (scores.mean()))
# Out:
# Mean ROC AUC: 0.84723

# %% [markdown]
# ## Tuning
# ### Fix learning rate and number of estimators for tuning tree-based parameters

# %%
# define grid
param_grid_1 = {'loss':['deviance', 'exponential'],'max_depth':[3,5,7],'max_features':[3,5],'n_estimators':[100,200,500],'learning_rate':[0.01,0.1,0.5]}
model = GradientBoostingClassifier(random_state=random_state)

# %%
# define evaluation procedure
from sklearn.model_selection import GridSearchCV
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# define grid search
grid = GridSearchCV(estimator=model, param_grid=param_grid_1, n_jobs=-1, cv=cv, scoring='roc_auc')
# execute the grid search
grid_result = grid.fit(X_train, y_train)
# report the best configuration
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.849797 using {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.831242 (0.016615) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.838435 (0.015923) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 200}
# 0.846813 (0.014811) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 500}
# 0.833323 (0.015561) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 100}
# 0.840147 (0.015033) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 200}
# 0.847511 (0.015311) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 500}
# 0.843891 (0.015427) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 100}
# 0.846325 (0.014929) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 200}
# 0.849257 (0.015089) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 500}
# 0.843459 (0.014458) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 100}
# 0.845498 (0.014850) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 200}
# 0.847492 (0.015343) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 500}
# 0.845824 (0.014321) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 100}
# 0.845999 (0.014121) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 200}
# 0.844361 (0.014229) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 500}
# 0.842733 (0.013973) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 100}
# 0.842838 (0.014103) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 200}
# 0.841014 (0.014717) with: {'learning_rate': 0.01, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 500}
# 0.832899 (0.016220) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.840364 (0.015285) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 200}
# 0.847567 (0.014820) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 500}
# 0.834556 (0.015376) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 100}
# 0.841080 (0.015229) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 200}
# 0.848348 (0.015159) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 500}
# 0.844832 (0.015135) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 100}
# 0.847070 (0.014735) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 200}
# 0.849161 (0.014650) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 500}
# 0.843254 (0.014341) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 100}
# 0.845574 (0.014570) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 200}
# 0.847083 (0.014748) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 500}
# 0.845848 (0.014531) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 100}
# 0.846190 (0.014158) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 200}
# 0.844155 (0.014153) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 500}
# 0.841901 (0.013955) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 100}
# 0.841763 (0.014081) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 200}
# 0.839628 (0.013986) with: {'learning_rate': 0.01, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 500}
# 0.849797 (0.015442) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.849378 (0.016006) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 200}
# 0.841950 (0.017223) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 500}
# 0.847962 (0.016000) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 100}
# 0.847373 (0.016260) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 200}
# 0.838380 (0.017848) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 500}
# 0.844764 (0.015895) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 100}
# 0.836802 (0.016768) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 200}
# 0.822680 (0.016377) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 500}
# 0.843125 (0.017682) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 100}
# 0.835246 (0.017816) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 200}
# 0.820579 (0.019214) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 500}
# 0.834943 (0.015712) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 100}
# 0.825856 (0.015700) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 200}
# 0.819767 (0.015195) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 500}
# 0.831122 (0.016550) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 100}
# 0.823937 (0.017380) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 200}
# 0.818389 (0.017092) with: {'learning_rate': 0.1, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 500}
# 0.849202 (0.015140) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.848646 (0.014722) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 200}
# 0.840292 (0.016247) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 500}
# 0.847873 (0.015838) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 100}
# 0.846384 (0.015848) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 200}
# 0.837589 (0.015901) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 500}
# 0.844724 (0.014681) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 100}
# 0.837277 (0.016354) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 200}
# 0.825628 (0.018141) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 500}
# 0.841738 (0.015037) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 100}
# 0.834484 (0.015475) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 200}
# 0.823564 (0.016282) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 500}
# 0.834484 (0.014855) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 100}
# 0.828008 (0.016555) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 200}
# 0.820833 (0.016906) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 500}
# 0.832529 (0.014252) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 100}
# 0.824885 (0.015410) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 200}
# 0.817551 (0.015041) with: {'learning_rate': 0.1, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 500}
# 0.832326 (0.016806) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.819939 (0.019750) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 200}
# 0.802569 (0.021791) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 3, 'max_features': 3, 'n_estimators': 500}
# 0.826880 (0.016370) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 100}
# 0.813040 (0.019460) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 200}
# 0.799438 (0.018281) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 3, 'max_features': 5, 'n_estimators': 500}
# 0.805067 (0.020838) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 100}
# 0.802225 (0.021308) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 200}
# 0.800769 (0.021214) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 5, 'max_features': 3, 'n_estimators': 500}
# 0.806757 (0.018677) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 100}
# 0.803804 (0.019398) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 200}
# 0.800570 (0.019297) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 5, 'max_features': 5, 'n_estimators': 500}
# 0.801646 (0.020356) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 100}
# 0.804135 (0.019794) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 200}
# 0.804142 (0.019617) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 7, 'max_features': 3, 'n_estimators': 500}
# 0.806209 (0.017796) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 100}
# 0.806943 (0.018624) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 200}
# 0.805021 (0.019314) with: {'learning_rate': 0.5, 'loss': 'deviance', 'max_depth': 7, 'max_features': 5, 'n_estimators': 500}
# 0.835293 (0.017133) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 100}
# 0.825871 (0.016763) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 200}
# 0.811215 (0.018983) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 3, 'n_estimators': 500}
# 0.829986 (0.017107) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 100}
# 0.818502 (0.017809) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 200}
# 0.808230 (0.019969) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 3, 'max_features': 5, 'n_estimators': 500}
# 0.814732 (0.015757) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 100}
# 0.807639 (0.017461) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 200}
# 0.802814 (0.017583) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 5, 'max_features': 3, 'n_estimators': 500}
# 0.813530 (0.015765) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 100}
# 0.807961 (0.015900) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 200}
# 0.801453 (0.017368) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 5, 'max_features': 5, 'n_estimators': 500}
# 0.811896 (0.014357) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 100}
# 0.809737 (0.016531) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 200}
# 0.808794 (0.020673) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 7, 'max_features': 3, 'n_estimators': 500}
# 0.810587 (0.018773) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 100}
# 0.807426 (0.017919) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 200}
# 0.805889 (0.017775) with: {'learning_rate': 0.5, 'loss': 'exponential', 'max_depth': 7, 'max_features': 5, 'n_estimators': 500}

# %%
gb_clf=GradientBoostingClassifier(max_features=3)
gb_clf.fit(X_train, y_train)
y_pred=gb_clf.predict(X_val)

# %%
print(classification_report(y_val, y_pred, digits=2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      1273
#            1       0.75      0.45      0.56       327
#
#     accuracy                           0.86      1600
#    macro avg       0.81      0.70      0.74      1600
# weighted avg       0.85      0.86      0.84      1600

# %%
# Plot non-normalized confusion matrix
disp = plot_confusion_matrix(gb_clf, X_val, y_val,cmap=plt.cm.Blues)
disp.ax_.set_title("Confusion matrix, without normalization")
plt.show()

# %% [markdown]
# ## ROC curve
#
# The ROC Curve is a useful diagnostic tool for understanding the trade-off for different thresholds and the ROC AUC provides a useful number for comparing models based on their general capabilities.
#
# If crisp class labels are required from a model under such an analysis, then an optimal threshold is required. This would be a threshold on the curve that is closest to the top-left of the plot.

# %%
from sklearn.metrics import roc_curve

# roc curve for models
fpr1, tpr1, thresh1 = roc_curve(y_val, knn.predict_proba(X_val)[:,1], pos_label=1)
fpr2, tpr2, thresh2 = roc_curve(y_val,logit.predict_proba(X_val)[:,1], pos_label=1)
fpr3, tpr3, thresh3 = roc_curve(y_val, tree.predict_proba(X_val)[:,1], pos_label=1)
fpr4, tpr4, thresh4 = roc_curve(y_val, rf.predict_proba(X_val)[:,1], pos_label=1)
fpr5, tpr5, thresh5 = roc_curve(y_val, gb_clf.predict_proba(X_val)[:,1], pos_label=1)

#roc curve for tpr = fpr 
random_probs = [0 for i in range(len(y_val))]
p_fpr, p_tpr, _ = roc_curve(y_val, random_probs, pos_label=1)

# %%
# matplotlib
import matplotlib.pyplot as plt
plt.style.use('seaborn')

# plot roc curves
plt.figure(1)
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='KNN')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='Logistic')
plt.plot(fpr3, tpr3, linestyle='--',color='red', label='DecisionTree')
plt.plot(fpr4, tpr4, linestyle='--',color='blue', label='RandomForest')
plt.plot(fpr5, tpr5, linestyle='--',color='yellow', label='GradientBoost')
plt.plot(p_fpr, p_tpr, linestyle='--', color='black')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROC',dpi=200)
plt.show();

plt.figure(2)
plt.xlim(0, 0.4)
plt.ylim(0.4, 1)
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='KNN')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='Logistic')
plt.plot(fpr3, tpr3, linestyle='--',color='red', label='DecisionTree')
plt.plot(fpr4, tpr4, linestyle='--',color='blue', label='RandomForest')
plt.plot(fpr5, tpr5, linestyle='--',color='yellow', label='GradientBoost')
plt.plot(p_fpr, p_tpr, linestyle='--', color='black')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROCzoom',dpi=200)
plt.show();

# %% [markdown]
# ## Threshold setting
#
# There are many ways we could locate the threshold with the optimal balance between false positive and true positive rates.
#
# Firstly, the true positive rate is called the Sensitivity. The inverse of the false-positive rate is called the Specificity.
#
# - Sensitivity = TruePositive / (TruePositive + FalseNegative)
# - Specificity = TrueNegative / (FalsePositive + TrueNegative)
# - Where:
# - Sensitivity = True Positive Rate
# - Specificity = 1 – False Positive Rate

# %% [markdown]
# The Geometric Mean or G-Mean is a metric for imbalanced classification that, if optimized, will seek a balance between the sensitivity and the specificity.
#
# G-Mean = sqrt(Sensitivity * Specificity)

# %%
# calculate the g-mean for each threshold
from numpy import argmax
from numpy import sqrt

# %% [markdown]
# We can also re-draw the ROC Curve and highlight this point.

# %%
# plot roc curves
plt.figure(1)
# calculate the g-mean for each threshold
gmeans_knn = sqrt(tpr1 * (1-fpr1))
gmeans_log = sqrt(tpr2 * (1-fpr2))
gmeans_rf = sqrt(tpr4 * (1-fpr4))
# locate the index of the largest g-mean
ix1 = argmax(gmeans_knn)
ix2 = argmax(gmeans_log)
ix3 = argmax(gmeans_rf)
print('Best Threshold KNN=%f, G-Mean=%.3f' % (thresh1[ix1], gmeans_knn[ix1]))
print('Best Threshold LOG =%f, G-Mean=%.3f' % (thresh2[ix2], gmeans_log[ix2]))
print('Best Threshold RF=%f, G-Mean=%.3f' % (thresh4[ix3], gmeans_rf[ix3]))
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='KNN')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='LOG')
plt.plot(fpr4, tpr4, linestyle='--',color='red', label='RandomForest')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.scatter(fpr1[ix1], tpr1[ix1], marker='o', color='black', label='Best')
plt.scatter(fpr2[ix2], tpr2[ix2], marker='o', color='black', label='Best')
plt.scatter(fpr4[ix3], tpr4[ix3], marker='o', color='black', label='Best')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROCbest',dpi=200)
plt.show();

plt.figure(2)
plt.xlim(0, 0.5)
plt.ylim(0.4, 1)
plt.plot(fpr1, tpr1, linestyle='--',color='orange', label='KNN')
plt.plot(fpr2, tpr2, linestyle='--',color='green', label='LOG')
plt.plot(fpr4, tpr4, linestyle='--',color='red', label='RandomForest')
plt.plot(p_fpr, p_tpr, linestyle='--', color='blue')
plt.scatter(fpr1[ix1], tpr1[ix1], marker='o', color='black', label='Best')
plt.scatter(fpr2[ix2], tpr2[ix2], marker='o', color='black', label='Best')
plt.scatter(fpr4[ix3], tpr4[ix3], marker='o', color='black', label='Best')
# title
plt.title('ROC curve')
# x label
plt.xlabel('False Positive Rate')
# y label
plt.ylabel('True Positive rate')

plt.legend(loc='best')
plt.savefig('ROCbestzoom',dpi=200)
plt.show();
# Out:
# Best Threshold KNN=0.238098, G-Mean=0.742
# Best Threshold LOG =0.237242, G-Mean=0.715
# Best Threshold RF=0.222780, G-Mean=0.779
